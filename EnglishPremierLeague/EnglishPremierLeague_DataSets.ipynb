# %% [markdown]
# # Create the data set for the project.

# %% [markdown]
# ## Load the data files for all 27 English Premier League seasons.

# %%
# import pandas library as pd.
import pandas as pd

# read in all 27 season of the English Premier League csv files.
EPL19_20 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_19-20.csv')
EPL18_19 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_18-19.csv')
EPL17_18 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_17-18.csv')
EPL16_17 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_16-17.csv')
EPL15_16 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_15-16.csv')
EPL14_15 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_14-15.csv')
EPL13_14 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_13-14.csv')
EPL12_13 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_12-13.csv')
EPL11_12 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_11-12.csv')
EPL10_11 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_10-11.csv')
EPL09_10 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_09-10.csv')
EPL08_09 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_08-09.csv')
EPL07_08 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_07-08.csv')
EPL06_07 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_06-07.csv')
EPL05_06 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_05-06.csv')
EPL04_05 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_04-05.csv')
EPL03_04 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_03-04.csv')
EPL02_03 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_02-03.csv')
EPL01_02 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_01-02.csv')
EPL00_01 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_00-01.csv')
EPL99_00 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_99-00.csv')
EPL98_99 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_98-99.csv')
EPL97_98 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_97-98.csv')
EPL96_97 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_96-97.csv')
EPL95_96 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_95-96.csv')
EPL94_95 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_94-95.csv')
EPL93_94 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_93-94.csv')

# %%
# merge all the data sets.
EPL = pd.concat([EPL93_94, EPL94_95, EPL95_96, EPL96_97, EPL97_98, 
                 EPL98_99, EPL99_00, EPL00_01, EPL01_02, EPL02_03, 
                 EPL03_04, EPL04_05, EPL05_06, EPL06_07, EPL07_08, 
                 EPL08_09, EPL09_10, EPL10_11, EPL11_12, EPL12_13, 
                 EPL13_14, EPL14_15, EPL15_16, EPL16_17, EPL17_18, 
                 EPL18_19, EPL19_20], sort=False, ignore_index=True)
# show the data frame shape.
print(EPL.shape)
# show the data frame with headers.
EPL.tail(100)
# Out:
# (10144, 161)
#       Div        Date        HomeTeam  ... MaxCAHA  AvgCAHH  AvgCAHA
# 10044  E0  09/08/2019       Liverpool  ...    2.07     1.90     1.99
# 10045  E0  10/08/2019        West Ham  ...    1.98     1.97     1.92
# 10046  E0  10/08/2019     Bournemouth  ...    1.96     1.96     1.92
# 10047  E0  10/08/2019         Burnley  ...    2.07     1.86     2.02
# 10048  E0  10/08/2019  Crystal Palace  ...    2.08     1.96     1.93
# ...    ..         ...             ...  ...     ...      ...      ...
# 10139  E0  26/10/2019         Burnley  ...    2.30     1.70     2.24
# 10140  E0  27/10/2019       Newcastle  ...    2.25     1.86     2.03
# 10141  E0  27/10/2019         Arsenal  ...    1.91     2.02     1.87
# 10142  E0  27/10/2019       Liverpool  ...    1.92     2.01     1.88
# 10143  E0  27/10/2019         Norwich  ...    2.15     1.84     2.06
#
# [100 rows x 161 columns]

# %%
EPL.HomeTeam.value_counts()
# Out:
# Everton             503
# Man United          503
# Liverpool           503
# Tottenham           503
# Arsenal             503
# Chelsea             503
# Newcastle           465
# West Ham            446
# Aston Villa         446
# Man City            408
# Southampton         370
# Blackburn           327
# Sunderland          304
# Fulham              266
# Leicester           254
# Bolton              247
# Middlesbrough       247
# West Brom           228
# Leeds               213
# Stoke               190
# Crystal Palace      178
# Coventry            156
# Charlton            152
# Wigan               152
# Norwich             142
# Sheffield Weds      137
# Wimbledon           137
# Swansea             133
# Derby               133
# Birmingham          133
# Portsmouth          133
# Watford             119
# QPR                 118
# Burnley             100
# Wolves              100
# Hull                 95
# Bournemouth          81
# Ipswich              80
# Nott'm Forest        78
# Reading              57
# Sheffield United     45
# Brighton             43
# Cardiff              38
# Bradford             38
# Huddersfield         38
# Oldham               21
# Swindon              21
# Blackpool            19
# Middlesboro          19
# Barnsley             19
# Name: HomeTeam, dtype: int64

# %%
# save a copy of the data set.
EPL.to_csv('EnglishPremierLeague.csv', index=False)
# !head EnglishPremierLeague.csv
# Out:
# Div,Date,HomeTeam,AwayTeam,FTHG,FTAG,FTR,HTHG,HTAG,HTR,Attendance,Referee,HS,AS,HST,AST,HHW,AHW,HC,AC,HF,AF,HO,AO,HY,AY,HR,AR,HBP,ABP,GBH,GBD,GBA,IWH,IWD,IWA,LBH,LBD,LBA,SBH,SBD,SBA,WHH,WHD,WHA,SYH,SYD,SYA,B365H,B365D,B365A,SOH,SOD,SOA,GB>2.5,GB<2.5,B365>2.5,B365<2.5,GBAHH,GBAHA,GBAH,LBAHH,LBAHA,LBAH,B365AHH,B365AHA,B365AH,BWH,BWD,BWA,SJH,SJD,SJA,VCH,VCD,VCA,Bb1X2,BbMxH,BbAvH,BbMxD,BbAvD,BbMxA,BbAvA,BbOU,BbMx>2.5,BbAv>2.5,BbMx<2.5,BbAv<2.5,BbAH,BbAHh,BbMxAHH,BbAvAHH,BbMxAHA,BbAvAHA,BSH,BSD,BSA,PSH,PSD,PSA,PSCH,PSCD,PSCA,Time,MaxH,MaxD,MaxA,AvgH,AvgD,AvgA,P>2.5,P<2.5,Max>2.5,Max<2.5,Avg>2.5,Avg<2.5,AHh,PAHH,PAHA,MaxAHH,MaxAHA,AvgAHH,AvgAHA,B365CH,B365CD,B365CA,BWCH,BWCD,BWCA,IWCH,IWCD,IWCA,WHCH,WHCD,WHCA,VCCH,VCCD,VCCA,MaxCH,MaxCD,MaxCA,AvgCH,AvgCD,AvgCA,B365C>2.5,B365C<2.5,PC>2.5,PC<2.5,MaxC>2.5,MaxC<2.5,AvgC>2.5,AvgC<2.5,AHCh,B365CAHH,B365CAHA,PCAHH,PCAHA,MaxCAHH,MaxCAHA,AvgCAHH,AvgCAHA
# E0,14/08/93,Arsenal,Coventry,0,3,A,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,14/08/93,Aston Villa,QPR,4,1,H,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,14/08/93,Chelsea,Blackburn,1,2,A,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,14/08/93,Liverpool,Sheffield Weds,2,0,H,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,14/08/93,Man City,Leeds,1,1,D,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,14/08/93,Newcastle,Tottenham,0,1,A,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,14/08/93,Oldham,Ipswich,0,3,A,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,14/08/93,Sheffield United,Swindon,3,1,H,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,14/08/93,Southampton,Everton,0,2,A,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,

# %%
# download the data set.
from google.colab import files 
files.download('EnglishPremierLeague.csv')

# %% [markdown]
# ## Create the 2019 Schedule.

# %%
EPL2019 = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/2019Schedule.csv')
print(EPL2019.shape)
EPL2019.head()
# Out:
# (381, 28)
#    Division    GameDate  ... HomeBookingPoints_Y5_R10 AwayBookingPoints_Y5_R10
# 0       NaN  09/08/2019  ...                      NaN                      NaN
# 1       NaN  10/08/2019  ...                      NaN                      NaN
# 2       NaN  10/08/2019  ...                      NaN                      NaN
# 3       NaN  10/08/2019  ...                      NaN                      NaN
# 4       NaN  10/08/2019  ...                      NaN                      NaN
#
# [5 rows x 28 columns]

# %%
EPL2019 = EPL2019['HomeTeam'].replace(['Tottenham Hotspur', 'Tottenham'])

# %%
EPL2019['HomeTeam'] = EPL2019['HomeTeam'].replace({'Tottenham Hotspur' : 'Tottenham',
'Norwich City'  : 'Norwich',
'Manchester City' : 'Man City',
'Southampton FC' : 'Southampton',
'Wolverhampton Wanderers' : 'Wolves',
'Chelsea FC' : 'Chelsea',
'Liverpool FC' : 'Liverpool',
'Brighton & Hove Albion' : 'Brighton',
'Burnley FC' : 'Burnley',
'Sheffield United' : 'Sheffield',
'Everton FC' : 'Everton',
'AFC Bournemouth' : 'Bournemouth',
'West Ham United'  : 'West Ham',
'Arsenal FC' : 'Arsenal',
'Watford FC' : 'Watford',
'Manchester United' : 'Man United',
'Newcastle United' : 'Newcastle',
'Leicester City' : 'Leicester',

})

# %%
EPL2019.HomeTeam.value_counts()
# Out:
# Brighton          19
# Aston Villa       19
# Wolves            19
# Arsenal           19
# Liverpool         19
# Tottenham         19
# Watford           19
# Southampton       19
# Newcastle         19
# West Ham          19
# Everton           19
# Chelsea           19
# Burnley           19
# Man United        19
# Sheffield         19
# Bournemouth       19
# Leicester         19
# Crystal Palace    19
# Man City          19
# Norwich           19
# Name: HomeTeam, dtype: int64

# %%
EPL.HomeTeam.value_counts()
# Out:
# Everton             503
# Man United          503
# Liverpool           503
# Tottenham           503
# Arsenal             503
# Chelsea             503
# Newcastle           465
# West Ham            446
# Aston Villa         446
# Man City            408
# Southampton         370
# Blackburn           327
# Sunderland          304
# Fulham              266
# Leicester           254
# Bolton              247
# Middlesbrough       247
# West Brom           228
# Leeds               213
# Stoke               190
# Crystal Palace      178
# Coventry            156
# Charlton            152
# Wigan               152
# Norwich             142
# Sheffield Weds      137
# Wimbledon           137
# Swansea             133
# Derby               133
# Birmingham          133
# Portsmouth          133
# Watford             119
# QPR                 118
# Burnley             100
# Wolves              100
# Hull                 95
# Bournemouth          81
# Ipswich              80
# Nott'm Forest        78
# Reading              57
# Sheffield United     45
# Brighton             43
# Cardiff              38
# Bradford             38
# Huddersfield         38
# Oldham               21
# Swindon              21
# Blackpool            19
# Middlesboro          19
# Barnsley             19
# Name: HomeTeam, dtype: int64

# %% [markdown]
# ## Create a 'Liverpool' football club data set.

# %%
# import pandas library.
import pandas as pd 

# read in the English Premier League data file.
EPL  = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague.csv')
print(EPL.shape)
EPL.tail(100)
# Out:
# (10144, 161)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (103) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       Div        Date        HomeTeam  ... MaxCAHA  AvgCAHH  AvgCAHA
# 10044  E0  09/08/2019       Liverpool  ...    2.07     1.90     1.99
# 10045  E0  10/08/2019        West Ham  ...    1.98     1.97     1.92
# 10046  E0  10/08/2019     Bournemouth  ...    1.96     1.96     1.92
# 10047  E0  10/08/2019         Burnley  ...    2.07     1.86     2.02
# 10048  E0  10/08/2019  Crystal Palace  ...    2.08     1.96     1.93
# ...    ..         ...             ...  ...     ...      ...      ...
# 10139  E0  26/10/2019         Burnley  ...    2.30     1.70     2.24
# 10140  E0  27/10/2019       Newcastle  ...    2.25     1.86     2.03
# 10141  E0  27/10/2019         Arsenal  ...    1.91     2.02     1.87
# 10142  E0  27/10/2019       Liverpool  ...    1.92     2.01     1.88
# 10143  E0  27/10/2019         Norwich  ...    2.15     1.84     2.06
#
# [100 rows x 161 columns]

# %%
# single out 'Liverpoool' in 'HomeTeam' & 'AwayTeam' colums.
LPFCH =  EPL[EPL['HomeTeam']=='Liverpool']
LPFCA =  EPL[EPL['AwayTeam']=='Liverpool']

# %%
# merge the 2 data sets to create an only 'Liverpool' data set.
LPFC_EPL = pd.concat([LPFCH, LPFCA], sort=False, ignore_index=True)
print(LPFC_EPL.shape)
LPFC_EPL.head()
# Out:
# (1005, 161)
#   Div      Date   HomeTeam        AwayTeam  ...  MaxCAHH  MaxCAHA AvgCAHH  AvgCAHA
# 0  E0  14/08/93  Liverpool  Sheffield Weds  ...      NaN      NaN     NaN      NaN
# 1  E0  25/08/93  Liverpool       Tottenham  ...      NaN      NaN     NaN      NaN
# 2  E0  28/08/93  Liverpool           Leeds  ...      NaN      NaN     NaN      NaN
# 3  E0  12/09/93  Liverpool       Blackburn  ...      NaN      NaN     NaN      NaN
# 4  E0  02/10/93  Liverpool         Arsenal  ...      NaN      NaN     NaN      NaN
#
# [5 rows x 161 columns]

# %%
# save a copy of the data set.
LPFC_EPL.to_csv('LiverpoolFootballClubData_EPL.csv', index=False)
# !head LiverpoolFootballClubData_EPL.csv
# Out:
# Div,Date,HomeTeam,AwayTeam,FTHG,FTAG,FTR,HTHG,HTAG,HTR,Attendance,Referee,HS,AS,HST,AST,HHW,AHW,HC,AC,HF,AF,HO,AO,HY,AY,HR,AR,HBP,ABP,GBH,GBD,GBA,IWH,IWD,IWA,LBH,LBD,LBA,SBH,SBD,SBA,WHH,WHD,WHA,SYH,SYD,SYA,B365H,B365D,B365A,SOH,SOD,SOA,GB>2.5,GB<2.5,B365>2.5,B365<2.5,GBAHH,GBAHA,GBAH,LBAHH,LBAHA,LBAH,B365AHH,B365AHA,B365AH,BWH,BWD,BWA,SJH,SJD,SJA,VCH,VCD,VCA,Bb1X2,BbMxH,BbAvH,BbMxD,BbAvD,BbMxA,BbAvA,BbOU,BbMx>2.5,BbAv>2.5,BbMx<2.5,BbAv<2.5,BbAH,BbAHh,BbMxAHH,BbAvAHH,BbMxAHA,BbAvAHA,BSH,BSD,BSA,PSH,PSD,PSA,PSCH,PSCD,PSCA,Time,MaxH,MaxD,MaxA,AvgH,AvgD,AvgA,P>2.5,P<2.5,Max>2.5,Max<2.5,Avg>2.5,Avg<2.5,AHh,PAHH,PAHA,MaxAHH,MaxAHA,AvgAHH,AvgAHA,B365CH,B365CD,B365CA,BWCH,BWCD,BWCA,IWCH,IWCD,IWCA,WHCH,WHCD,WHCA,VCCH,VCCD,VCCA,MaxCH,MaxCD,MaxCA,AvgCH,AvgCD,AvgCA,B365C>2.5,B365C<2.5,PC>2.5,PC<2.5,MaxC>2.5,MaxC<2.5,AvgC>2.5,AvgC<2.5,AHCh,B365CAHH,B365CAHA,PCAHH,PCAHA,MaxCAHH,MaxCAHA,AvgCAHH,AvgCAHA
# E0,14/08/93,Liverpool,Sheffield Weds,2,0,H,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,25/08/93,Liverpool,Tottenham,1,2,A,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,28/08/93,Liverpool,Leeds,2,0,H,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,12/09/93,Liverpool,Blackburn,0,1,A,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,02/10/93,Liverpool,Arsenal,0,0,D,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,16/10/93,Liverpool,Oldham,2,1,H,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,30/10/93,Liverpool,Southampton,4,2,H,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,06/11/93,Liverpool,West Ham,2,0,H,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# E0,28/11/93,Liverpool,Aston Villa,2,1,H,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,

# %%
# download the data set.
from google.colab import files 
files.download('LiverpoolFootballClubData_EPL.csv')

# %% [markdown]
# ## Load the English Premier League 2019-2020 Schedule.

# %%
# import the pandas library.
import pandas as pd 

# read in the 2019 season of the English Premier League csv file.
EPL_schedule = pd.read_csv('https://raw.githubusercontent.com/CVanchieri/LSDS-DataSets/master/EnglishPremierLeagueData/EnglishPremierLeague_Schedule.csv')
print(EPL_schedule.shape)
EPL_schedule.head()
# Out:
# (380, 28)
#    Division  GameDate  ... HomeBookingPoints_Y5_R10 AwayBookingPoints_Y5_R10
# 0       NaN  09/08/19  ...                      NaN                      NaN
# 1       NaN  10/08/19  ...                      NaN                      NaN
# 2       NaN  10/08/19  ...                      NaN                      NaN
# 3       NaN  10/08/19  ...                      NaN                      NaN
# 4       NaN  10/08/19  ...                      NaN                      NaN
#
# [5 rows x 28 columns]

# %%
# single out 'Liverpoool' in 'HomeTeam' & 'AwayTeam' colums.
LPFCH =  EPL_schedule[EPL_schedule['HomeTeam']=='Liverpool']
LPFCA =  EPL_schedule[EPL_schedule['AwayTeam']=='Liverpool']

# %%
# merge the 2 data sets to create an only 'Liverpool' data set.
LPFC_EPL_schedule = pd.concat([LPFCH, LPFCA], sort=False, ignore_index=True)
print(LPFC_EPL_schedule.shape)
LPFC_EPL_schedule.head()
# Out:
# (38, 28)
#    Division  GameDate  ... HomeBookingPoints_Y5_R10 AwayBookingPoints_Y5_R10
# 0       NaN  09/08/19  ...                      NaN                      NaN
# 1       NaN  24/08/19  ...                      NaN                      NaN
# 2       NaN  14/09/19  ...                      NaN                      NaN
# 3       NaN  05/10/19  ...                      NaN                      NaN
# 4       NaN  27/10/19  ...                      NaN                      NaN
#
# [5 rows x 28 columns]

# %%
# save a copy of the data set.
LPFC_EPL_schedule.to_csv('LiverpoolFootballClubEPL_Schedule.csv', index=False)
# !head LiverpoolFootballClubEPL_Schedule.csv
# Out:
# Division,GameDate,HomeTeam,AwayTeam,FullTimeHomeGoals,FullTimeAwayGoals,FullTimeResult,HalfTimeHomeGoals,HalfTimeAwayGoals,HalfTimeResult,HomeShots,AwayShots,HomeShotsOnTarget,AwayShotsOnTarget,HomeShotsHitFrame,AwayShotsHitFrame,HomeCorners,AwayCorners,HomeFouls,AwayFouls,HomeOffSides,AwayOffSides,HomeYellowCards,AwayYellowCards,HomeRedCards,AwayRedCards,HomeBookingPoints_Y5_R10,AwayBookingPoints_Y5_R10
# ,09/08/19,Liverpool,Norwich,,,,,,,,,,,,,,,,,,,,,,,,
# ,24/08/19,Liverpool,Arsenal,,,,,,,,,,,,,,,,,,,,,,,,
# ,14/09/19,Liverpool,Newcastle,,,,,,,,,,,,,,,,,,,,,,,,
# ,05/10/19,Liverpool,Leicester,,,,,,,,,,,,,,,,,,,,,,,,
# ,27/10/19,Liverpool,Spurs,,,,,,,,,,,,,,,,,,,,,,,,
# ,09/11/19,Liverpool,Man City,,,,,,,,,,,,,,,,,,,,,,,,
# ,30/11/19,Liverpool,Brighton,,,,,,,,,,,,,,,,,,,,,,,,
# ,04/12/19,Liverpool,Everton,,,,,,,,,,,,,,,,,,,,,,,,
# ,14/12/19,Liverpool,Watford,,,,,,,,,,,,,,,,,,,,,,,,

# %%
# download the data set.
from google.colab import files 
files.download('LiverpoolFootballClubEPL_Schedule.csv')
